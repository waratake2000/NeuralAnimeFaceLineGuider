# %%
import webuiapi

# create API client
api = webuiapi.WebUIApi()

# create API client with custom host, port
api = webuiapi.WebUIApi(host='10.8.76.222', port=7860)

# create API client with custom host, port and https
#api = webuiapi.WebUIApi(host='webui.example.com', port=443, use_https=True)

# create API client with default sampler, steps.
#api = webuiapi.WebUIApi(sampler='Euler a', steps=20)

# optionally set username, password when --api-auth=username:password is set on webui.
# username, password are not protected and can be derived easily if the communication channel is not encrypted.
# you can also pass username, password to the WebUIApi constructor.
# api.set_auth('username', 'password')
result1 = api.txt2img(prompt="anime,face,beautiful,master peice",
                    negative_prompt="ugly, out of frame",
                    # seed=1003,
                    styles=["anime"],
                    cfg_scale=7,
#                      sampler_index='DDIM',
#                      steps=30,
#                      enable_hr=True,
#                      hr_scale=2,
#                      hr_upscaler=webuiapi.HiResUpscaler.Latent,
#                      hr_second_pass_steps=20,
#                      hr_resize_x=1536,
#                      hr_resize_y=1024,
#                      denoising_strength=0.4,

                    )
# images contains the returned images (PIL images)
result1.images

# image is shorthand for images[0]
result1.image

# info contains text info about the api call
result1.info

# info contains paramteres of the api call
result1.parameters


result1.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
import cv2
img = cv2.imread('test.png')

# img2img with multiple ControlNets (used 1.0 but also supports 1.1)
unit1 = webuiapi.ControlNetUnit(input_image=img, module='canny', model='control_canny-fp16 [e3fe7712]')
unit2 = webuiapi.ControlNetUnit(input_image=img, module='depth', model='control_depth-fp16 [400750f6]', weight=0.5)

r2 = api.img2img(prompt="girl",
            images=[img], 
            width=512,
            height=512,
            controlnet_units=[unit1, unit2],
            sampler_name="Euler a",
            cfg_scale=7,
           )
r2.image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 8
#       5 unit1 = webuiapi.ControlNetUnit(input_image=img, module='canny', model='control_canny-fp16 [e3fe7712]')
#       6 unit2 = webuiapi.ControlNetUnit(input_image=img, module='depth', model='control_depth-fp16 [400750f6]', weight=0.5)
# ----> 8 r2 = api.img2img(prompt="girl",
#       9             images=[img],
#      10             width=512,
#      11             height=512,
#      12             controlnet_units=[unit1, unit2],
#      13             sampler_name="Euler a",
#      14             cfg_scale=7,
#      15            )
#      16 r2.image
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:425, in WebUIApi.img2img(self, images, resize_mode, denoising_strength, image_cfg_scale, mask_image, mask_blur, inpainting_fill, inpaint_full_res, inpaint_full_res_padding, inpainting_mask_invert, initial_noise_multiplier, prompt, styles, seed, subseed, subseed_strength, seed_resize_from_h, seed_resize_from_w, sampler_name, batch_size, n_iter, steps, cfg_scale, width, height, restore_faces, tiling, do_not_save_samples, do_not_save_grid, negative_prompt, eta, s_churn, s_tmax, s_tmin, s_noise, override_settings, override_settings_restore_afterwards, script_args, sampler_index, include_init_images, script_name, send_images, save_images, alwayson_scripts, controlnet_units, use_deprecated_controlnet, use_async)
#     421 if script_args is None:
#     422     script_args = []
#     424 payload = {
# --> 425     "init_images": [b64_img(x) for x in images],
#     426     "resize_mode": resize_mode,
#     427     "denoising_strength": denoising_strength,
#     428     "mask_blur": mask_blur,
#     429     "inpainting_fill": inpainting_fill,
#     430     "inpaint_full_res": inpaint_full_res,
#     431     "inpaint_full_res_padding": inpaint_full_res_padding,
#     432     "inpainting_mask_invert": inpainting_mask_invert,
#     433     "initial_noise_multiplier": initial_noise_multiplier,
#     434     "prompt": prompt,
#     435     "styles": styles,
#     436     "seed": seed,
#     437     "subseed": subseed,
#     438     "subseed_strength": subseed_strength,
#     439     "seed_resize_from_h": seed_resize_from_h,
#     440     "seed_resize_from_w": seed_resize_from_w,
#     441     "batch_size": batch_size,
#     442     "n_iter": n_iter,
#     443     "steps": steps,
#     444     "cfg_scale": cfg_scale,
#     445     "image_cfg_scale": image_cfg_scale,
#     446     "width": width,
#     447     "height": height,
#     448     "restore_faces": restore_faces,
#     449     "tiling": tiling,
#     450     "do_not_save_samples": do_not_save_samples,
#     451     "do_not_save_grid": do_not_save_grid,
#     452     "negative_prompt": negative_prompt,
#     453     "eta": eta,
#     454     "s_churn": s_churn,
#     455     "s_tmax": s_tmax,
#     456     "s_tmin": s_tmin,
#     457     "s_noise": s_noise,
#     458     "override_settings": override_settings,
#     459     "override_settings_restore_afterwards": override_settings_restore_afterwards,
#     460     "sampler_name": sampler_name,
#     461     "sampler_index": sampler_index,
#     462     "include_init_images": include_init_images,
#     463     "script_name": script_name,
#     464     "script_args": script_args,
#     465     "send_images": send_images,
#     466     "save_images": save_images,
#     467     "alwayson_scripts": alwayson_scripts,
#     468 }
#     469 if mask_image is not None:
#     470     payload["mask"] = b64_img(mask_image)
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:425, in <listcomp>(.0)
#     421 if script_args is None:
#     422     script_args = []
#     424 payload = {
# --> 425     "init_images": [b64_img(x) for x in images],
#     426     "resize_mode": resize_mode,
#     427     "denoising_strength": denoising_strength,
#     428     "mask_blur": mask_blur,
#     429     "inpainting_fill": inpainting_fill,
#     430     "inpaint_full_res": inpaint_full_res,
#     431     "inpaint_full_res_padding": inpaint_full_res_padding,
#     432     "inpainting_mask_invert": inpainting_mask_invert,
#     433     "initial_noise_multiplier": initial_noise_multiplier,
#     434     "prompt": prompt,
#     435     "styles": styles,
#     436     "seed": seed,
#     437     "subseed": subseed,
#     438     "subseed_strength": subseed_strength,
#     439     "seed_resize_from_h": seed_resize_from_h,
#     440     "seed_resize_from_w": seed_resize_from_w,
#     441     "batch_size": batch_size,
#     442     "n_iter": n_iter,
#     443     "steps": steps,
#     444     "cfg_scale": cfg_scale,
#     445     "image_cfg_scale": image_cfg_scale,
#     446     "width": width,
#     447     "height": height,
#     448     "restore_faces": restore_faces,
#     449     "tiling": tiling,
#     450     "do_not_save_samples": do_not_save_samples,
#     451     "do_not_save_grid": do_not_save_grid,
#     452     "negative_prompt": negative_prompt,
#     453     "eta": eta,
#     454     "s_churn": s_churn,
#     455     "s_tmax": s_tmax,
#     456     "s_tmin": s_tmin,
#     457     "s_noise": s_noise,
#     458     "override_settings": override_settings,
#     459     "override_settings_restore_afterwards": override_settings_restore_afterwards,
#     460     "sampler_name": sampler_name,
#     461     "sampler_index": sampler_index,
#     462     "include_init_images": include_init_images,
#     463     "script_name": script_name,
#     464     "script_args": script_args,
#     465     "send_images": send_images,
#     466     "save_images": save_images,
#     467     "alwayson_scripts": alwayson_scripts,
#     468 }
#     469 if mask_image is not None:
#     470     payload["mask"] = b64_img(mask_image)
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:114, in b64_img(image)
#     113 def b64_img(image: Image) -> str:
# --> 114     return "data:image/png;base64," + raw_b64_img(image)
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:121, in raw_b64_img(image)
#     119 with io.BytesIO() as output_bytes:
#     120     metadata = None
# --> 121     for key, value in image.info.items():
#     122         if isinstance(key, str) and isinstance(value, str):
#     123             if metadata is None:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
# txt2img with ControlNet (used 1.0 but also supports 1.1)
import cv2
import base64
from PIL import Image

img = cv2.imread('test.png')

# Encode into PNG and send to ControlNet
# retval, bytes = cv2.imencode('.png', img)

# numpy_imageはnumpy.ndarray型の画像データを示します
pil_image = Image.fromarray(img)
# encoded_image = base64.b64encode(bytes).decode('utf-8')
unit1 = webuiapi.ControlNetUnit(input_image=pil_image, module='openpose_faceonly', model='control_v11p_sd15_openpose [cab727d4]')

r = api.txt2img(prompt="anime face",cfg_scale=7, controlnet_units=[unit1])
# Out:
# WebUIApiResult(images=[<PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F7728D1E190>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F7728D1E400>], parameters={'enable_hr': False, 'denoising_strength': 0.7, 'firstphase_width': 0, 'firstphase_height': 0, 'hr_scale': 2.0, 'hr_upscaler': 'Latent', 'hr_second_pass_steps': 0, 'hr_resize_x': 0, 'hr_resize_y': 0, 'hr_sampler_name': None, 'hr_prompt': '', 'hr_negative_prompt': '', 'prompt': 'anime face', 'styles': [], 'seed': -1, 'subseed': -1, 'subseed_strength': 0.0, 'seed_resize_from_h': 0, 'seed_resize_from_w': 0, 'sampler_name': 'Euler a', 'batch_size': 1, 'n_iter': 1, 'steps': 20, 'cfg_scale': 7.0, 'width': 512, 'height': 512, 'restore_faces': False, 'tiling': False, 'do_not_save_samples': False, 'do_not_save_grid': False, 'negative_prompt': '', 'eta': 1.0, 's_min_uncond': 0.0, 's_churn': 0.0, 's_tmax': 0.0, 's_tmin': 0.0, 's_noise': 1.0, 'override_settings': {}, 'override_settings_restore_afterwards': True, 'script_args': [], 'sampler_index': 'Euler a', 'script_name': None, 'send_images': True, 'save_images': False, 'alwayson_scripts': {'ControlNet': {'args': [{'input_image': '...', 'mask': None, 'module': 'openpose_faceonly', 'model': 'control_v11p_sd15_openpose [cab727d4]', 'weight': 1.0, 'resize_mode': 'Resize and Fill', 'lowvram': False, 'processor_res': 512, 'threshold_a': 64, 'threshold_b': 64, 'guidance': 1.0, 'guidance_start': 0.0, 'guidance_end': 1.0, 'control_mode': 0, 'pixel_perfect': False}]}}}, info={'prompt': 'anime face', 'all_prompts': ['anime face'], 'negative_prompt': '', 'all_negative_prompts': [''], 'seed': 3552016963, 'all_seeds': [3552016963], 'subseed': 4240875438, 'all_subseeds': [4240875438], 'subseed_strength': 0.0, 'width': 512, 'height': 512, 'sampler_name': 'Euler a', 'cfg_scale': 7.0, 'steps': 20, 'batch_size': 1, 'restore_faces': False, 'face_restoration_model': None, 'sd_model_hash': 'c6bbc15e32', 'seed_resize_from_w': 0, 'seed_resize_from_h': 0, 'denoising_strength': 0.7, 'extra_generation_params': {'ControlNet 0': 'preprocessor: openpose_faceonly, model: control_v11p_sd15_openpose [cab727d4], weight: 1.0, starting/ending: (0.0, 1.0), resize mode: Resize and Fill, pixel perfect: False, control mode: 0, preprocessor params: (512, 64, 64)'}, 'index_of_first_image': 0, 'infotexts': ['anime face\nSteps: 20, Sampler: Euler a, CFG scale: 7.0, Seed: 3552016963, Size: 512x512, Model hash: c6bbc15e32, Model: sd-v1-5-inpainting, Denoising strength: 0.7, Conditional mask weight: 1, ControlNet 0: "preprocessor: openpose_faceonly, model: control_v11p_sd15_openpose [cab727d4], weight: 1.0, starting/ending: (0.0, 1.0), resize mode: Resize and Fill, pixel perfect: False, control mode: 0, preprocessor params: (512, 64, 64)", Version: v1.4.0'], 'styles': [], 'job_timestamp': '20230721173535', 'clip_skip': 1, 'is_using_inpainting_conditioning': True})

# %%
r = api.controlnet_detect(images=[pil_image], module='openpose_faceonly')
r.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=610x512>

# %%
r.image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# txt2img with ControlNet (used 1.0 but also supports 1.1)
import cv2
import base64

img = cv2.imread('test.png')

# Encode into PNG and send to ControlNet
# retval, bytes = cv2.imencode('.png', img)
# encoded_image = base64.b64encode(bytes).decode('utf-8')
unit1 = webuiapi.ControlNetUnit(input_image=img, module='openpose_faceonly', model='control_v11p_sd15_openpose [cab727d4]')
# unit1.json()
r = api.txt2img(prompt="photo of a beautiful girl", controlnet_units=[unit1])
# r.image
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 12
#      10 unit1 = webuiapi.ControlNetUnit(input_image=img, module='openpose_faceonly', model='control_v11p_sd15_openpose [cab727d4]')
#      11 # unit1.json()
# ---> 12 r = api.txt2img(prompt="photo of a beautiful girl", controlnet_units=[unit1])
#      13 # r.image
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:338, in WebUIApi.txt2img(self, enable_hr, denoising_strength, firstphase_width, firstphase_height, hr_scale, hr_upscaler, hr_second_pass_steps, hr_resize_x, hr_resize_y, prompt, styles, seed, subseed, subseed_strength, seed_resize_from_h, seed_resize_from_w, sampler_name, batch_size, n_iter, steps, cfg_scale, width, height, restore_faces, tiling, do_not_save_samples, do_not_save_grid, negative_prompt, eta, s_churn, s_tmax, s_tmin, s_noise, override_settings, override_settings_restore_afterwards, script_args, script_name, send_images, save_images, alwayson_scripts, controlnet_units, sampler_index, use_deprecated_controlnet, use_async)
#     332     return self.custom_post(
#     333         "controlnet/txt2img", payload=payload, use_async=use_async
#     334     )
#     336 if controlnet_units and len(controlnet_units) > 0:
#     337     payload["alwayson_scripts"]["ControlNet"] = {
# --> 338         "args": [x.to_dict() for x in controlnet_units]
#     339     }
#     340 elif self.has_controlnet:
#     341     # workaround : if not passed, webui will use previous args!
#     342     payload["alwayson_scripts"]["ControlNet"] = {"args": []}
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:338, in <listcomp>(.0)
#     332     return self.custom_post(
#     333         "controlnet/txt2img", payload=payload, use_async=use_async
#     334     )
#     336 if controlnet_units and len(controlnet_units) > 0:
#     337     payload["alwayson_scripts"]["ControlNet"] = {
# --> 338         "args": [x.to_dict() for x in controlnet_units]
#     339     }
#     340 elif self.has_controlnet:
#     341     # workaround : if not passed, webui will use previous args!
#     342     payload["alwayson_scripts"]["ControlNet"] = {"args": []}
#
# File /usr/local/lib/python3.8/dist-packages/webuiapi/webuiapi.py:95, in ControlNetUnit.to_dict(self)
#      93 def to_dict(self):
#      94     return {
# ---> 95         "input_image": raw_b64_img(self.input_image) if self.input_image else "",
#      96         "mask": raw_b64_img(self.mask) if self.mask is not None else None,
#      97         "module": self.module,
#      98         "model": self.model,
#      99         "weight": self.weight,
#     100         "resize_mode": self.resize_mode,
#     101         "lowvram": self.lowvram,
#     102         "processor_res": self.processor_res,
#     103         "threshold_a": self.threshold_a,
#     104         "threshold_b": self.threshold_b,
#     105         "guidance": self.guidance,
#     106         "guidance_start": self.guidance_start,
#     107         "guidance_end": self.guidance_end,
#     108         "control_mode": self.control_mode,
#     109         "pixel_perfect": self.pixel_perfect,
#     110     }
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
api.controlnet_model_list()
# Out:
# ['control_canny-fp16 [e3fe7712]',
#  'control_depth-fp16 [400750f6]',
#  'control_hed-fp16 [13fee50b]',
#  'control_mlsd-fp16 [e3705cfa]',
#  'control_normal-fp16 [63f96f7c]',
#  'control_openpose-fp16 [9ca67cc5]',
#  'control_scribble-fp16 [c508311e]',
#  'control_seg-fp16 [b9c1cc12]',
#  'control_v11p_sd15_openpose [cab727d4]',
#  't2iadapter_canny-fp16 [f2e7f7cd]',
#  't2iadapter_color-fp16 [743b5c62]',
#  't2iadapter_depth-fp16 [2c829a81]',
#  't2iadapter_keypose-fp16 [e3943bb9]',
#  't2iadapter_openpose-fp16 [4286314e]',
#  't2iadapter_seg-fp16 [0e677718]',
#  't2iadapter_sketch-fp16 [75b15924]',
#  't2iadapter_style-fp16 [0e2e8330]']
